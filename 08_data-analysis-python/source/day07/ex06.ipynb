# %%
import requests

response = requests.get("https://news.naver.com/section/105")

# JS 코드 범위 좁히기
data = response.text.split('data-template-id="SECTION_HEADLINE">')[1]  # [1]: 이 문자열로 쪼개진 뒤쪽을 가져온다.
data = data.split("_SECTION_HEADLINE_MORE_BUTTON_WRAP")[0]  # [0]: 이 문자열로 쪼개진 앞쪽을 가져온다.
data = data.split('sa_list">')[1]
data = data.split(r'</ul>')[0]
print(data)
# Out:
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/031/0000937198" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000D6_000000000000000000937198" data-imp-url="https://n.news.naver.com/mnews/article/031/0000937198" data-imp-index="1">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/031/2025/06/02/937198.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="넷마블, 오픈월드 RPG &#x27;일곱 개의 대죄: 오리진&#x27; 사전등록 시작" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/031/0000937198" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000D6_000000000000000000937198" data-imp-url="https://n.news.naver.com/mnews/article/031/0000937198" data-imp-index="1">
# 							<strong class="sa_text_strong">넷마블, 오픈월드 RPG &#x27;일곱 개의 대죄: 오리진&#x27; 사전등록 시작</strong>
# 						</a>
# 						<div class="sa_text_lede">넷마블(대표 김병규)은 신작 &#x27;일곱 개의 대죄: 오리진&#x27;의 브랜드 사이트를 오픈하고 사전 등록을 시작했다고 2일 밝혔다. 브랜드 사이트는 &#x27;일곱 개의 대죄&#x27;의 무대인 브리타니아의 전경을 바라보는 멜리오다스, 트리스탄</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">아이뉴스24</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/031/0000937198" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news031,0000937198" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202506020850_00000770/section/105?oid&#x3D;031&amp;aid&#x3D;0000937198" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">8</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/277/0005602025" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="88000385_000000000000000005602025" data-imp-url="https://n.news.naver.com/mnews/article/277/0005602025" data-imp-index="2">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/277/2025/06/02/5602025.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="국가 AI컴퓨팅센터, 13일까지 재공고…공모요건 그대로" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/277/0005602025" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="88000385_000000000000000005602025" data-imp-url="https://n.news.naver.com/mnews/article/277/0005602025" data-imp-index="2">
# 							<strong class="sa_text_strong">국가 AI컴퓨팅센터, 13일까지 재공고…공모요건 그대로</strong>
# 						</a>
# 						<div class="sa_text_lede">신청자가 없어 유찰됐던 국가AI컴퓨팅센터 구축 사업이 오는 13일까지 재공고를 진행한다. 이번 재공고에서도 공모 요건은 변경 없이 그대로 진행된다. 과학기술정보통신부는 국가AI컴퓨팅센터 구축 사업 재공고(연장 공고)</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">아시아경제</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/277/0005602025" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news277,0005602025" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202506011310_00000116/section/105?oid&#x3D;277&amp;aid&#x3D;0005602025" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">17</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/016/0002479789" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="8800010E_000000000000000002479789" data-imp-url="https://n.news.naver.com/mnews/article/016/0002479789" data-imp-index="3">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/016/2025/06/02/2479789.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="KB손보, LGU+·스몰티켓과 데이터 기반 차세대 車보험 개발 나선다" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/016/0002479789" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="8800010E_000000000000000002479789" data-imp-url="https://n.news.naver.com/mnews/article/016/0002479789" data-imp-index="3">
# 							<strong class="sa_text_strong">KB손보, LGU+·스몰티켓과 데이터 기반 차세대 車보험 개발 나선다</strong>
# 						</a>
# 						<div class="sa_text_lede">FMS 실시간 운행 정보 교류 통해 보험 개발·보험료 할인·위험 관리 법인 고객 대상 특약·설루션 제공 2일 서울 용산구 LG유플러스 용산 사옥에서 열린 실시간 차량 데이터 기반 상품 개발을 위한 위한 3자 간 업무</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">헤럴드경제</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/016/0002479789" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news016,0002479789" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202506020910_00000015/section/105?oid&#x3D;016&amp;aid&#x3D;0002479789" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">26</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/421/0008287199" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="08138263_000000000000000008287199" data-imp-url="https://n.news.naver.com/mnews/article/421/0008287199" data-imp-index="4">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/421/2025/06/01/8287199.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="&quot;풀프레임 리더십 AI설루션 이식&quot;…캐논코리아 &#x27;100년기업&#x27; 선언" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/421/0008287199" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="08138263_000000000000000008287199" data-imp-url="https://n.news.naver.com/mnews/article/421/0008287199" data-imp-index="4">
# 							<strong class="sa_text_strong">&quot;풀프레임 리더십 AI설루션 이식&quot;…캐논코리아 &#x27;100년기업&#x27; 선언</strong>
# 						</a>
# 						<div class="sa_text_lede">김민석 기자 &#x27;세상의 모든 순간, 캐논으로 완성하다. 찰나의 감동, 선명한 기록&#x27; 1985년 롯데그룹과 일본 캐논사의 50대50 합작으로 출범한 캐논코리아(옛 롯데캐논)는 이달 열린 40주년 기념식에서 새로운 슬로건</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">뉴스1</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/421/0008287199" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news421,0008287199" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202506021000_00000129/section/105?oid&#x3D;421&amp;aid&#x3D;0008287199" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">6</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/001/0015425900" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000D8_000000000000000015425900" data-imp-url="https://n.news.naver.com/mnews/article/001/0015425900" data-imp-index="5">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/001/2025/06/02/15425900.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="금융 보안 프로그램 의무 설치가 오히려 해킹 위험 높인다" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/001/0015425900" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000D8_000000000000000015425900" data-imp-url="https://n.news.naver.com/mnews/article/001/0015425900" data-imp-index="5">
# 							<strong class="sa_text_strong">금융 보안 프로그램 의무 설치가 오히려 해킹 위험 높인다</strong>
# 						</a>
# 						<div class="sa_text_lede">KAIST &quot;키보드 입력 훔쳐보기·인증서 노출 우려…의무화 바꿔야&quot; 국내 금융 보안 프로그램의 설치 의무화가 오히려 사이버 공격 위험성을 높인다는 연구 결과가 나왔다. 한국과학기술원(KAIST) 전기·전자공학부 김용</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">연합뉴스</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/001/0015425900" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news001,0015425900" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202506020820_00000002/section/105?oid&#x3D;001&amp;aid&#x3D;0015425900" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">22</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE is_blind">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/018/0006028850" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000E7_000000000000000006028850" data-imp-url="https://n.news.naver.com/mnews/article/018/0006028850" data-imp-index="6">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/018/2025/06/01/6028850.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="SKT, 유심 교체 569만명 기록…교체율 62%" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/018/0006028850" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000E7_000000000000000006028850" data-imp-url="https://n.news.naver.com/mnews/article/018/0006028850" data-imp-index="6">
# 							<strong class="sa_text_strong">SKT, 유심 교체 569만명 기록…교체율 62%</strong>
# 						</a>
# 						<div class="sa_text_lede">SK텔레콤(017670) 유심(USIM) 정보 해킹 사고 이후 유심 교체를 받은 사람이 누적 569만 명으로 집계됐다. 남은 대기자는 346만 명으로 교체율은 60%를 넘었다. 1일 SK텔레콤 뉴스룸에 따르면 지난 </div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">이데일리</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/018/0006028850" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news018,0006028850" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202506011340_00000112/section/105?oid&#x3D;018&amp;aid&#x3D;0006028850" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">13</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE is_blind">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/092/0002376701" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="8800011E_000000000000000002376701" data-imp-url="https://n.news.naver.com/mnews/article/092/0002376701" data-imp-index="7">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/092/2025/06/02/2376701.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="&quot;삼성, 갤S26에 &#x27;퍼플렉시티 AI&#x27; 탑재 논의 중&quot;" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/092/0002376701" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="8800011E_000000000000000002376701" data-imp-url="https://n.news.naver.com/mnews/article/092/0002376701" data-imp-index="7">
# 							<strong class="sa_text_strong">&quot;삼성, 갤S26에 &#x27;퍼플렉시티 AI&#x27; 탑재 논의 중&quot;</strong>
# 						</a>
# 						<div class="sa_text_lede">삼성전자가 내년 상반기 출시할 스마트폰 &#x27;갤럭시 S26&#x27;에 퍼플렉시티 AI의 인공지능(AI) 서비스가 탑재될 수 있다는 가능성이 제기됐다. 블룸버그는 2일(현지시간) 익명의 익명 소식통을 인용해 삼성전자가 미국 AI</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">지디넷코리아</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/092/0002376701" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news092,0002376701" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202506020940_00000104/section/105?oid&#x3D;092&amp;aid&#x3D;0002376701" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">12</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE is_blind">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/008/0005202399" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000C2_000000000000000005202399" data-imp-url="https://n.news.naver.com/mnews/article/008/0005202399" data-imp-index="8">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/008/2025/06/02/5202399.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="K-보안솔루션에 꽂힌 일본, 소프트캠프 &quot;비용효율적 보안해법 제시&quot;" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/008/0005202399" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000C2_000000000000000005202399" data-imp-url="https://n.news.naver.com/mnews/article/008/0005202399" data-imp-index="8">
# 							<strong class="sa_text_strong">K-보안솔루션에 꽂힌 일본, 소프트캠프 &quot;비용효율적 보안해법 제시&quot;</strong>
# 						</a>
# 						<div class="sa_text_lede">내부망과 외부망 사이의 연계를 통한 정보 시스템 혁신을 도모하는 일본이 한국형 보안 솔루션에 꽂혔다. 정보보안 전문기업 소프트캠프의 일본시장 성과가 가시화될 것이란 기대감도 함께 커진다. 소프트캠프는 지난달 30일 </div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">머니투데이</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/008/0005202399" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news008,0005202399" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202506021130_00000108/section/105?oid&#x3D;008&amp;aid&#x3D;0005202399" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">7</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
