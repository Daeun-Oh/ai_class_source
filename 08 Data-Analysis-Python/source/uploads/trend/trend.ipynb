# %%
# konlpy : 한국어 형태소 분석기
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (from konlpy) (1.5.2)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (from konlpy) (5.4.0)
# Requirement already satisfied: numpy>=1.6 in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (from konlpy) (2.2.6)
# Requirement already satisfied: packaging in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (from JPype1>=0.7.0->konlpy) (25.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install jpype1
# Out:
# Requirement already satisfied: jpype1 in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (1.5.2)
# Requirement already satisfied: packaging in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (from jpype1) (25.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 워드 클라우드
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (from wordcloud) (2.2.6)
# Requirement already satisfied: pillow in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (from wordcloud) (11.2.1)
# Requirement already satisfied: matplotlib in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (from wordcloud) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (from matplotlib->wordcloud) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\desktop\daeun-ai\08 data-analysis-python\source\basic\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install Counter
# Out:
# Collecting Counter
#   Using cached Counter-1.0.0.tar.gz (5.2 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       Traceback (most recent call last):
#         File "C:\Users\admin\Desktop\Daeun-ai\08 Data-Analysis-Python\source\basic\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#           main()
#         File "C:\Users\admin\Desktop\Daeun-ai\08 Data-Analysis-Python\source\basic\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\admin\Desktop\Daeun-ai\08 Data-Analysis-Python\source\basic\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 143, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\admin\AppData\Local\Temp\pip-build-env-v527vmp_\overlay\Lib\site-packages\setuptools\build_meta.py", line 331, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\admin\AppData\Local\Temp\pip-build-env-v527vmp_\overlay\Lib\site-packages\setuptools\build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#         File "C:\Users\admin\AppData\Local\Temp\pip-build-env-v527vmp_\overlay\Lib\site-packages\setuptools\build_meta.py", line 512, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "C:\Users\admin\AppData\Local\Temp\pip-build-env-v527vmp_\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#           exec(code, locals())
#         File "<string>", line 32, in <module>
#         File "<string>", line 13, in getLongDescription
#       UnicodeDecodeError: 'cp949' codec can't decode byte 0xe2 in position 2095: illegal multibyte sequence
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !pip freeze > requirements.txt

# %%
import requests
from bs4 import BeautifulSoup as bs

html = requests.get("https://news.naver.com/").text
soup = bs(html, 'html.parser')

body = soup.select_one("body")

# 불필요한 키워드는 제거할 것

text = body.get_text().strip().replace("\n", " ")
stopwords = ['본문', '바로가기', 'NAVER', '검색', '이슈', '닫기', '구독'] # 불용어

text
# Out:
# '본문 바로가기        NAVER  뉴스   엔터     스포츠     날씨     프리미엄     대선           검색             언론사별 정치 경제 사회 생활/문화 IT/과학 세계 랭킹 신문보기 오피니언 TV 팩트체크 알고리즘 안내 정정보도 모음              콘텐츠   6.5(목)   전체 언론사 뉴스스탠드 라이브러리           언론사편집  기자                                                 연재                                                                  구독설정                                       속보     코스피 11개월 만에 장중 2800선 돌파    한국일보       코스피 장중 2800선 돌파…10개월여만    국민일보  내용작성전      코스피 이틀째 급등…2,800선도 돌파    연합뉴스TV       트럼프 “하버드대 다니려는 외국 학생 입국 제한 필요”    헤럴드경제       코스피, 장중 2800선 돌파    파이낸셜뉴스  내용작성전      \'이재명 랠리\' 코스피 2800돌파…환율도 1350원대    노컷뉴스       외국인 매수에 코스피 2,800선 돌파...연고점 재경신    YTN  내용작성전      SK하이닉스 ‘불기둥’, 코스피 장중 2800선 돌파…10개월여만    서울신문       조희대, 대법관 증원법에 “공론장 마련 희망…국회와 계속협의”    국제신문       트럼프 "하버드대 다니려는 외국 학생 입국 제한 필요"    TV조선  내용작성전      코스피 장중 2800선 돌파…10개월여만    아시아경제  내용작성전      코스피 장중 2800선 돌파…10개월여만    매일경제  내용작성전      코스피 장중 2800선 돌파…10개월여만    SBS Biz  내용작성전      김민석 “지금은 제2의 IMF… 민생과 통합 매일 가슴에 새기겠다”    강원일보       코스피 2800선 돌파···지난해 7월 이후 10개월 만    경향신문       코스피, 11개월 만에 장중 2800선 돌파    한국경제  내용작성전      조희대, 대법관 증원법에 "공론장 마련 희망…국회와 계속협의"    대전일보       새 정부 기대에 코스피 2800 돌파…지난해 7월 19일 이후 321일만    서울경제       코스피, 2,800선 \'돌파\'…외국인, 매수세 \'후끈\'    한국경제TV       코스피 장중 2,800선 돌파…10개월여만    연합뉴스  내용작성전      이재명 취임 이튿날, 코스피 2800선 돌파…11개월 만    뉴스1  내용작성전      조희대, 대법관 증원법에 "국가 백년대계가 걸린 문제… 공론장 마련되길"    부산일보       조희대, 대법관 증원법에 “국가 백년대계 걸려… 공론장 마련 희망”    세계일보       공수처, 방첩사 `군 블랙리스트` 수사…장성 정치성향 수집의혹    디지털타임스       김민석 "제2의 IMF 상황…국민 집단지성 받드는 정부 될 것"    경기일보       조희대, 대법관 증원법에 "공론장 마련 희망…국회와 계속 협의"    머니투데이  내용작성전     속보 닫기             경기일보 06월 05일 10:06  구독      [속보] 김민석 "제2의 IMF 상황…국민 집단지성 받드는 정부 될 것"    “헤어진 연인에게 연락하려고”…前여친 친구 흉기협박·폭행에 납치까지 한 중국인   李대통령 경호 경찰전담경호대 철수…경호처로 인계   전한길 "대선 패배, 이준석·한동훈 때문…尹 등에 칼 꽂아"            연합뉴스 06월 05일 10:08  구독      [속보] 코스피 장중 2,800선 돌파…10개월여만    조희대, 대법관 증원법에 "공론장 마련 희망…국회와 협의"   李대통령 경호 경찰전담경호대 철수…경호처로 인계(종합)   [속보] 트럼프 "하버드대 다니려는 외국 학생 입국 제한 필요"            채널A 06월 05일 09:50  구독      李대통령, 취임 이튿날 국무회의 주재…민생회복에 속도전    민주, 오늘 ‘3대 특검법’ 처리…국힘 “입법 독재” 반발   이재명 대통령, 비상경제점검 TF 회의 주재…“좋은 정책 제안달라”   장예찬 “김문수, 패배 다음 날 턱걸이…당권 도전 의지 보인 것” [정치시그널]            주간경향 06월 05일 10:07  구독      김민석 “제2 IMF같은 어려운 상황···민생·통합 새기겠다”    조희대, 대법관 증원법에 “공론장 마련 희망···국회와 협의”   이 대통령, 국무총리 김민석·국정원장 이종석 지명   “문재인 정부 선견지명이 유혈 쿠데타 막았다”            YTN 06월 05일 10:08  구독   [속보] 외국인 매수에 코스피 2,800선 돌파...연고점 재경신    [현장영상+] 이 대통령, 취임 이틀째 안가에서 대통령실로 출근   [현장영상+] 국무총리 후보 김민석 "알아서 전력투구하라는 지명으로 생각하고 있어"   한미 정상 첫 통화 오늘 진행될 듯...주한미군 조정 언급할까?            전자신문 06월 05일 07:30  구독      北 스마트폰의 섬뜩한 기능… “5분마다 화면 캡처해 전송”    머스크, 백악관 나가자마자… 트럼프 감세 법안에 “역겹고 혐오스러워”   배민 \'장보기·쇼핑\', 2만원 이상 주문 시 무료배달   백악관 대변인, 韓 대선 입장 질의받자 서류 뒤적…“여기 있었는데”            헤럴드경제 06월 05일 10:01  구독      [속보] 코스피 장중 2800선 돌파…10개월여만    경제 총력전도 ‘실무형’…이재명式 스타일 ‘명분보다 실리’ [이런정치]   이재명 첫날 완성된 ‘26조 체코 잭팟’…두달 만에 2.1배 오른 ‘원전 대장주’, 더 오를까 [투자360]   김재원 “김문수, 평당원으로 돌아왔다…결정적 패인, 후보 교체 작업”            SBS 06월 05일 09:33  구독      조희대, 대법관 증원법에 "공론장 마련 희망…국회와 협의"    \'3대 특검법\' 오늘 본회의 처리…속도 조절 \'고심\'   백신도 치료제도 없는데…모기 물린 뒤 \'확진\'   "청와대 쪽에서 연기가" 화재 신고…알고 보니            매경이코노미 06월 04일 22:53  구독      [속보]  민주, 이재명 대통령 첫날 ‘대법관 증원법’ 처리…16명 늘려 30명    [속보] 李 “용산 대통령실 무덤같아…컴퓨터·필기도구·프린터기 없어”   “김혜경에 첫눈에 반했다”…초짜 변호사의 결혼 성공 비결은 ‘일기장’   홍준표 “상대 이재명이라 이길 게임이었는데…분탕질치다 또 이 꼴”            더스쿠프 06월 05일 09:44  구독      [재테크 Lab] 통신비 멤버십 혜택 살펴보셨나요?    이프랜드, 컬러버스, 제페토 휘청:  메타버스서 \'하차하는\' 기업들   "사용자 반토막" 테무 5월의 악몽, 데 미니미스가 뭐기에… [Global]\xa0 \xa0   "나 교체하면 불륜 폭로" 사람 협박한 AI [Global]            디지털데일리 06월 04일 16:58  구독      [이재명 당선] \'균형발전\' 기조에 쏠린 눈…소부장 생태계, 재편 신호탄    [이재명 당선] 게임 국내 질병코드 등재 막을까…게임업계 기대감 고조   배터리 사용량 40% 올라도 점유율 하락한 K-배터리…CATL·BYD \'폭풍 성장\' [소부장박대리]   [스노우플레이크 서밋] 샘 올트먼이 말한 ‘모두가 쓰는 AI’ 조건은?            신동아 06월 05일 10:09  구독      “붕괴 조짐에도 보강 못 하는 韓 건설 현장 구조적 문제”    [이재명 파워 엘리트 111] 김민석 국무총리 후보자   [이재명 파워 엘리트 111] 강훈식 대통령실 비서실장   [이재명 파워 엘리트 111] 이종석 국정원장 후보자            국민일보 06월 05일 10:08  구독      [속보] 코스피 장중 2800선 돌파…10 ...

# %% [markdown]
# ### konlpy.tag.Okt
# - Okt (Open Korean Text): KoNLPy에서 제공하는 한국어 형태소 분석기
# - `morphs(텍스트)` : 형태소 단위로 텍스트를 분리, 단어 단위로 분리된 리스트 반환
# - pos(text, norm=False, stem=False) : 형태로를 분리할 때 품사(명사, 동사, 형용사, 조사, ...) 정보를 함께 반환 / part of speech (품사)
#     - norm=True : 문장을 정규화 ("ㅋㅋ" -> "ㅋ")
#     - stem=True: 어간 추출 ("먹었다" -> "먹다)
#
# > 형태소: 의미를 가진 최소 단위

# %%
from konlpy.tag import Okt  # 트위터가 만든 형태 분석기
okt = Okt()

# %%
okt.morphs("나는 멋진 학원에 갑니다.")
# Out:
# ['나', '는', '멋진', '학원', '에', '갑니다', '.']

# %%
okt.pos("나는 멋진 학원에 갑니다.")
# Out:
# [('나', 'Noun'),
#  ('는', 'Josa'),
#  ('멋진', 'Adjective'),
#  ('학원', 'Noun'),
#  ('에', 'Josa'),
#  ('갑니다', 'Verb'),
#  ('.', 'Punctuation')]

# %%
words = okt.pos(text)
words[:10]
# Out:
# [('본문', 'Noun'),
#  ('바로가기', 'Noun'),
#  ('NAVER', 'Alpha'),
#  ('뉴스', 'Noun'),
#  ('엔터', 'Noun'),
#  ('스포츠', 'Noun'),
#  ('날씨', 'Noun'),
#  ('프리미엄', 'Noun'),
#  ('대선', 'Noun'),
#  ('검색', 'Noun')]

# %%
# 품사 별로 토큰화
words = []
for word, pos in okt.pos(text):
    if word not in stopwords and pos in ['Noun', 'Verb', 'Adjective']:
        words.append(word)
words[:10]
# Out:
# ['뉴스', '엔터', '스포츠', '날씨', '프리미엄', '대선', '언론', '사별', '정치', '경제']

# %% [markdown]
# ## ["키워드": 등장횟수] 형태로 가공하자!

# %%
from collections import Counter

stat = Counter(words)
stat
# Out:
# Counter({'이재명': 91,
#          '대통령': 90,
#          '정부': 47,
#          '속보': 42,
#          '신문': 37,
#          '코스피': 37,
#          '법': 34,
#          '돌파': 33,
#          '보기': 30,
#          '선': 30,
#          '대법관': 29,
#          '조희': 28,
#          '증원': 28,
#          '해보세요': 28,
#          '국민': 27,
#          '것': 27,
#          '장': 25,
#          '관심': 25,
#          '대선': 24,
#          '트럼프': 24,
#          '김민석': 24,
#          '개월': 23,
#          '일보': 23,
#          '공론장': 23,
#          '마련': 23,
#          '경제': 22,
#          '희망': 22,
#          '국회': 22,
#          '경호': 22,
#          '이': 21,
#          '만': 20,
#          '협의': 20,
#          '의': 19,
#          '대': 19,
#          '민생': 17,
#          '경찰': 17,
#          '명': 17,
#          '제': 16,
#          '뉴스': 15,
#          '새': 14,
#          '모두': 14,
#          '총리': 14,
#          '기자': 13,
#          '계속': 13,
#          '통합': 13,
#          '첫': 13,
#          '원전': 13,
#          '할': 13,
#          '힘': 13,
#          '상황': 12,
#          '철수': 12,
#          '등': 12,
#          '언론': 11,
#          '내용': 11,
#          '성전': 11,
#          '이후': 11,
#          '시대': 11,
#          '되겠다': 11,
#          '실용': 11,
#          '정치': 10,
#          '한국': 10,
#          '취임': 10,
#          '경기': 10,
#          '전담': 10,
#          '경호처': 10,
#          '패배': 10,
#          '김문수': 10,
#          '체코': 10,
#          '기업': 10,
#          '당선': 10,
#          '중': 10,
#          '기사': 10,
#          '시장': 10,
#          '조선': 9,
#          '수사': 9,
#          '인계': 9,
#          '이준석': 9,
#          '된': 9,
#          '후보자': 9,
#          '위': 9,
#          '민주당': 9,
#          '바란다': 9,
#          '출범': 9,
#          '수': 9,
#          '연재': 8,
#          '설정': 8,
#          '지난해': 8,
#          '부산': 8,
#          '될': 8,
#          '특검법': 8,
#          '처리': 8,
#          '같은': 8,
#          '후보': 8,
#          '해': 8,
#          '더': 8,
#          '하는': 8,
#          '성장': 8,
#          '세': 8,
#          '내란': 8,
#          '확인': 8,
#          '주의': 8,
#          '점': 7,
#          '서울': 7,
#          '국가': 7,
#          '한': 7,
#          '오늘': 7,
#          '비상': 7,
#          '영상': 7,
#          '대통령실': 7,
#          '계약': 7,
#          '위기': 7,
#          '비즈': 7,
#          '공약': 7,
#          '우려': 7,
#          '안': 7,
#          '방송': 7,
#          '관세': 7,
#          '협상': 7,
#          '김건희': 7,
#          '개': 7,
#          '왜': 7,
#          '사별': 6,
#          '전체': 6,
#          '언론사': 6,
#          '필요': 6,
#          '외국인': 6,
#          '정책': 6,
#          '듯': 6,
#          '백악관': 6,
#          '민주주의': 6,
#          '논란': 6,
#          '검찰': 6,
#          '보수': 6,
#          '이유': 6,
#          '두': 6,
#          '새정부': 6,
#          '선거': 6,
#          '투표': 6,
#          '입국': 5,
#          '매일경제': 5,
#          '대전': 5,
#          '기대': 5,
#          '문제': 5,
#          '사': 5,
#          '받': 5,
#          '민주': 5,
#          '국힘': 5,
#          '머스크': 5,
#          '뒤': 5,
#          '게임': 5,
#          '박': 5,
#          '건설': 5,
#          '단독': 5,
#          '개혁': 5,
#          '재': 5,
#          '중단': 5,
#          '했다': 5,
#          '최종': 5,
#          '여성': 5,
#          '길': 5,
#          '득표': 5,
#          '윤석열': 5,
#          '후': 5,
#          '국정': 5,
#          '삼성': 5,
#          '공식': 5,
#          '최': 5,
#          '법원': 5,
#          '부동산': 5,
#          '시작': 5,
#          '계엄': 5,
#          '아이': 5,
#          '됩니다': 5,
#          '있습니다': 5,
#          '세계': 4,
#          '연합뉴스': 4,
#          '하버드대': 4,
#          '제한': 4,
#          '파이낸셜뉴스': 4,
#          '국제': 4,
#          '매일': 4,
#          '새기겠다': 4,
#          '이튿날': 4,
#          '되길': 4,
#          '의혹': 4,
#          '집단지성': 4,
#          '한동훈': 4,
#          '종합': 4,
#          '회복': 4,
#          '도전': 4,
#          '점검': 4,
#          '당권': 4,
#          '어려운': 4,
#          '국무총리': 4,
#          '현장': 4,
#          '한미': 4,
#          '전자신문': 4,
#          '법안': 4,
#          '달': 4,
#          '배': 4,
#          '교체': 4,
#          '청와대': 4,
#          '데': 4,
#          '하면': 4,
#          '업계': 4,
#          '대감': 4,
#          '말': 4,
#          '금지': 4,
#          '없다': 4,
#          '다시': 4,
#          '발언': 4,
#          '지역': 4,
#          '수출': 4,
#          '몸싸움': 4,
#          '산': 4,
#          '축하': 4,
#          '있다': 4,
#          '송치': 4,
#          '로': 4,
#          '보조금': 4,
#          '해야': 4,
#          '따': 4,
#          '비자': 4,
#          '분열': 4,
#          '용': 4,
#          '복귀': 4,
#          '남편': 4,
#          '구속': 4,
#          '임기': 4,
#          '될까': 4,
#          '사망': 4,
#          '하기': 4,
#          '건': 4,
#          '방산': 4,
#          '강국': 4,
#          '기': 4,
#          '때': 4,
#          '김용태': 4,
#          '살': 4,
#          '오마이': 4,
#          '머니': 4,
#          '곳': 4,
#          '가동': 4,
#          '기획': 4,
#          '도움말': 4,
#          '제공': 4,
#          '최신': 4,
#          '홈플러스': 4,
#          '팩트': 3,
#          '콘텐츠': 3,
#          '편집': 3,
#          '국민일보': 3,
#          '이틀': 3,
#          '다니려는': 3,
#          '외국': 3,
#          '학생': 3,
#          '노컷뉴스': 3,
#          '매수': 3,
#          '신': 3,
#          '하이닉스': 3,
#          '지금': 3,
#          '강원': 3,
#          '백년': 3,
#          '대계': 3,
#          '처': 3,
#          '군': 3,
#          '장성': 3,
#          '정치성향': 3,
#          '수집': 3,
#          '협박': 3,
#          '주재': 3,
#          '회의': 3,
#          '좋은': 3,
#          '달라': 3,
#          '다음': 3,
#          '지명': 3,
#          '문재인': 3,
#          '통화': 3,
#          '진행': 3,
#          '언급': 3,
#          '첫날': 3,
#          '투자': 3,
#          '본회의': 3,
#          '홍준표': 3,
#          '상대': 3,
#          '일리': 3,
#          '폭풍': 3,
#          '대리': 3,
#          '조짐': 3,
#          '못': 3,
#          '파워': 3,
#          '엘리트': 3,
#          '하늘': 3,
#          '들': 3,
#          '나라': 3,
#          '책임': 3,
#          '종식': 3,
#          '정상화': 3,
#          '수주': 3,
#          '주목': 3,
#          '재판': 3,
#          '부부': 3,
#          '김상욱': 3,
#          '윤': 3,
#          '체결': 3,
#          '제주': 3,
#          '바다': 3,
#          '소년': 3,
#          '표': 3,
#          '한겨레': 3,
#          '국민주권': 3,
#          '꼭': 3,
#          '번': 3,
#          '강조': 3,
#          '이전': 3,
#          '합니다': 3,
#          '북한': 3,
#          '거부권': 3,
#          '사진': 3,
#          '리': 3,
#          '박스': 3,
#          '댓글': 3,
#          '코리아': 3,
#          '이행': 3,
#          '김': 3,
#          '장사': 3,
#          '반도체': 3,
#          '무슨': 3,
#          '갈등': 3,
#          '비공개': 3,
#          '가상': 3,
#          '혜인': 3,
#          '전면': 3,
#          '수도': 3,
#          '의대': 3,
#          '사기': 3,
#          '는': 3,
#          '극복': 3,
#          '우선': 3,
#          '방향': 3,
#          '불법': 3,
#          '담긴': 3,
#          '향': 3,
#          '환경': 3,
#          '외교': 3,
#          '침묵': 3,
#          '가장': 3,
#          '무단': 3,
#          '칼럼': 3,
#          '메시지': 3,
#          '보다': 3,
#          '일': 3,
#          '중국': 3,
#          '당내': 3,
#          '무너져': 3,
#          '정권': 3,
#          '가': 3,
#          '감량': 3,
#          '호': 3,
#          '함': 3,
#          '진보': 3,
#          '드립니다': 3,
#          '규제': 3,
#          '끝': 3,
#          '싸움': 3,
#          '창간': 3,
#          '기념': 3,
#          '백두산': 3,
#          '특집': 3,
#          '진짜': 3,
#          '동아일보': 3,
#          '안정': 3,
#          '구': 3,
#          '과제': 3,
#          '역사': 3,
#          '면': 3,
#          '박정희': 3,
#          '행정명령': 3,
#          '섬기는': 3,
#          '심층': 3,
#          '중견': 3,
#          '해부': 3,
#          '내': 3,
#          '최근': 3,
#          '이내': 3,
#          '작성': 3,
#          '리스트': 3,
#          '하세요': 3,
#          '추천': 3,
#          '하시면': 3,
#          '전쟁': 3,
#          '보호': 3,
#          '파면': 3,
#          '질문': 3,
#          '취임선서': 3,
#          '가자': 3,
#          '동영상': 3,
#          '탄핵': 3,
#          '문화': 2,
#          '안내': 2,
#          '보도': 2,
#          '선도': 2,
#          '헤럴드경제': 2,
#          '랠리': 2,
#          '환율': 2,
#          '연고': 2,
#          '재경': 2,
#          '불기둥': 2,
#          '아시아': 2,
#          '경향신문': 2,
#          '매수세': 2,
#          '후끈': 2,
#          '년대': 2,
#          '걸린': 2,
#          '걸려': 2,
#          '방첩': 2,
#          '블랙리스트': 2,
#          '디지털타임스': 2,
#          '드는': 2,
#          '머니투데이': 2,
#          '전한길': 2,
#          '국무회의': 2,
#          '입법': 2,
#          '독재': 2,
#          '제안': 2,
#          '날': 2,
#          '의지': 2,
#          '국정원장': 2,
#          '이종석': 2,
#          '전력': 2,
#          '투구': 2,
#          '생각': 2,
#          '정상': 2,
#          '미군': 2,
#          '조정': 2,
#          '할까': 2,
#          '감세': 2,
#          '여기': 2,
#          '오른': 2,
#          '김재원': 2,
#          '평': 2,
#          '결정': 2,
#          '패인': 2,
#          '작업': 2,
#          '제도': 2,
#          '화재': 2,
#          '신고': 2,
#          '용산': 2,
#          '무덤': 2,
#          '없어': 2,
#          '눈': 2,
#          '성공': 2,
#          '또': 2,
#          '버스': 2,
#          '나': 2,
#          '사람': 2,
#          '디지털': 2,
#          '부장': 2,
#          '고조': 2,
#          '배터리': 2,
#          '율': 2,
#          '강훈': 2,
#          '비서실': 2,
#          '대법': 2,
#          '임명': 2,
#          '사법': 2,
#          '포': 2,
#          '서명': 2,
#          '젊은': 2,
#          '미래': 2,
#          '대화': 2,
#          '답': 2,
#          '요구': 2,
#          '토론': 2,
#          '출신': 2,
#          '개막': 2,
#          '강세': 2,
#          '규명': 2,
#          '권성동': 2,
#          '리스크': 2,
#          '없는': 2,
#          '발견': 2,
#          '하던': 2,
#          '부진': 2,
#          '전화번호': 2,
#          '공개': 2,
#          '지정': 2,
#          '깜깜': 2,
#          '의원': 2,
#          '도부': 2,
#          '사퇴': 2,
#          '바라카': 2,
#          '쾌거': 2,
#          '종이': 2,
#          '돼야': 2,
#          '싫어': 2,
#          '지지': 2,
#          '명칭': 2,
#          '확정': 2,
#          '처음': 2,
#          '워치': 2,
#          '당국': 2,
#          '잰': 2,
#          '걸음': 2,
#          '동문': 2,
#          '중앙대': 2,
#          '배출': 2,
#          '곳곳': 2,
#          '현수막': 2,
#          '방지': 2,
#          '효과': 2,
#          '빙': 2,
#          '린다': 2,
#          '사실': 2,
#          '특검': 2,
#          '사태': 2,
#          '흔들리는': 2,
#          '친윤': 2,
#          '김종인': 2,
#          '돼': 2,
#          '첫째': 2,
#          '둘째': 2,
#          '공백': 2,
#          '블': 2,
#          '여행': 2,
#          '쿨': 2,
#          '압수수색': 2,
#          '지명자': 2,
#          '률': 2,
#          '인당': 2,
#          '국민총소득': 2,
#          '얼굴': 2,
#          '예방': 2,
#          '큰': 2,
#          '상무': 2,
#          '세력': 2,
#          '할머니': 2,
#          '강력': 2,
#          '촉구': 2,
#          '집': 2,
#          '찐': 2,
#          '남국': 2,
#          '비서': 2,
#          '관': 2,
#          '합류': 2,
#          '관광': 2,
#          '신속': 2,
#          '검토': 2,
#          '원': 2,
#          '전망': 2,
#          '차례': 2,
#          '사이비': 2,
#          '레밍': 2,
#          '집단': 2,
#          '중요한': 2,
#          '가지': 2,
#          '대신': 2,
#          '청년': 2,
#          '중앙': 2,
#          '역대': 2,
#          '자산': 2,
#          '비': 2,
#          '금융': 2,
#          '내부': 2,
#          '질': 2,
#          '최혁진': 2,
#          '제명': 2,
#          '파괴': 2,
#          '사기꾼': 2,
#          '예정': 2,
#          '착수': 2,
#          '대리투표': 2,
#          '사무': 2,
#          '일치': 2,
#          '찾아': 2,
#          '위성': 2,
#          '해킹': 2,
#          '충돌': 2,
#          '닻': 2,
#          '올린': 2,
#          '일본': 2,
#          '아야': 2,
#          '약': 2,
#          '위해': 2,
#          '다양한': 2,
#          '성사': 2,
#          '급': 2,
#          '대법원': 2,
#          '바람직한': 2,
#          '한수원': 2,
#          '소': 2,
#          '신분증': 2,
#          '한강로': 2,
#          '이제': 2,
#          '자세': 2,
#          '남성': 2,
#          '충북': 2,
#          '목소리': 2,
#          '위원장': 2,
#          '통일': 2,
#          '광주': 2,
#          '입건': 2,
#          '의견': 2,
#          '글로벌': 2,
#          '커져': 2,
#          '북극항로': 2,
#          '개척': 2,
#          '해양': 2,
#          '아닌': 2,
#          '리더': 2,
#          '품격': 2,
#          '뉴시스': 2,
#          '논의': 2,
#          '무엇': 2,
#          '앞': 2,
#          '가능성': 2,
#          '맹비': 2,
#          '프레': 2,
#          '영향력': 2,
#          '조선일보': 2,
#          '공론': 2,
#          '최저': 2,
#          '운동': 2,
#          '지속': 2,
#          '대한': 2,
#          '끝내고': 2,
#          '안보': 2,
#          '미국': 2,
#          '공격': 2,
#          '큰절': 2,
#          '사죄': 2,
#          '체제': 2,
#          '보세요': 2,
#          '공무원': 2,
#          '지배구조': 2,
#          '리포트': 2,
#          '그룹': 2,
#          '전선': 2,
#          '전략': 2,
#          '대한민국': 2,
#          '걸어온': 2,
#          '대응': 2,
#          '월간': 2,
#          '상승': 2,
#          '동력': 2,
#          '고객': 2,
#          '도입': 2,
#          '돌린': 2,
#          '누가': 2,
#          '오류': 2,
#          '수도권': 2,
#          '보고': 2,
#          '여부': 2,
#          '별': 2,
#          '무': 2,
#          '공': 2,
#          '캠프': 2,
#          '사의': 2,
#          '표명': 2,
#          '주': 2,
#          '지지율': 2,
#          '콘크리트': 2,
#          '뚫지': 2,
#          '실린': 2,
#          '쓴다': 2,
#          '조직': 2,
#          '통과': 2,
#          '성': 2,
#          '두고': 2,
#          '간섭': 2,
#          '자택': 2,
#          '완화': 2,
#          '주택': 2,
#          '건설업': 2,
#          '넥타이': 2,
#          '도약': 2,
#          '자동': 2,
#          '해당': 2,
#          '겨냥': 2,
#          '권': 2,
#          '이었다': 2,
#          '동맹': 2,
#          '관련': 2,
#          '이번': 2,
#          '를': 2,
#          '선언': 2,
#          '각': 2,
#          '판': 2,
#          '산업': 2,
#          '전': 2,
#          '여사': 2,
#          '인근': 2,
#          '샤넬': 2,
#          '취임식': 2,
#          '전공': 2,
#          '피': 2,
#          '박정훈': 2,
#          '그': 2,
#          '현안': 2,
#          '즉시': 2,
#          '육상': 2,
#          '대회': 2,
#          '벌금': 2,
#          '부과': 2,
#          '미': 2,
#          '이스라엘': 2,
#          '클릭': 2,
#          '정사': 2,
#          '동반': 2,
#          '반대': 2,
#          '당론': 2,
#          '무효': 2,
#          '서비스': 2,
#          '저작권': 2,
#          '엔터': 1,
#          '스포츠': 1,
#          '날씨': 1,
#          '프리미엄': 1,
#          '사회': 1,
#          '생활': 1,
#          '과학': 1,
#          '랭킹': 1,
#          '피니언': 1,
#          '체크': 1,
#          '알고리즘': 1,
#          '정정': 1,
#          '모음': 1,
#          '목': 1,
#          '뉴스스탠드': 1,
#          '라이브러리': 1,
#          '급등': 1,
#          '가슴': 1,
#          '헤어진': 1,
#          '연인': 1,
#          '연락': 1,
#          '하려고': 1,
#          '여친': 1,
#          '친구': 1,
#          '흉기': 1,
#          '폭행': 1,
#          '납치': 1,
#          '중국인': 1,
#          '때문': 1,
#          '칼': 1,
#          '꽂아': 1,
#          '채널': 1,
#          '반발': 1,
#          '예찬': 1,
#          '턱걸이': 1,
#          '보인': 1,
#          '시그널': 1,
#          '주간경향': 1,
#          '선견지명': 1,
#          '유혈': 1,
#          '쿠데타': 1,
#          '막았다': 1,
#          '안가에서': 1,
#          '출근': 1,
#          '알아서': 1,
#          '있어': 1,
#          '스마트폰': 1,
#          '섬뜩한': 1,
#          '기능': 1,
#          '화면': 1,
#          '캡처': 1,
#          '전송': 1,
#          '나가자마자': 1,
#          '역겹고': 1,
#          '혐오': 1,
#          '스러워': 1,
#          '배민': 1,
#          '장보기': 1,
#          '쇼핑': 1,
#          '이상': 1,
#          '주문': 1,
#          '시': 1,
#          '무료': 1,
#          '배달': 1,
#          '대변인': 1,
#          '입장': 1,
#          '질의': 1,
#          '받자': 1,
#          '서류': 1,
#          '있었는데': 1,
#          '총력전': 1,
#          '실무': 1,
#          '스타일': 1,
#          '명분': 1,
#          '실리': 1,
#          '완성': 1,
#          '잭팟': 1,
#          '장주': 1,
#          '오를까': 1,
#          '당원': 1,
#          '돌아왔다': 1,
#          '속도': 1,
#          '조절': 1,
#          '고심': 1,
#          '백신': 1,
#          '치료': 1,
#          '없는데': 1,
#          '모기': 1,
#          '물린': 1,
#          '확진': 1,
#          '쪽': 1,
#          '연기': 1,
#          '알': 1,
#          '보니': 1,
#          '매경이코노미': 1,
#          '늘려': 1,
#          '같아': 1,
#          '컴퓨터': 1,
#          '필기': 1,
#          '도구': 1,
#          '프린터기': 1,
#          '김혜경': 1,
#          '반했다': 1,
#          '초': 1,
#          '짜': 1,
#          '변호사': 1,
#          '결혼': 1,
#          '비결': 1,
#          '일기장': 1,
#          '이길': 1,
#          '이었는데': 1,
#          '분탕': 1,
#          '질치다': 1,
#          '꼴': 1,
#          '스쿠프': 1,
#          '재테크': 1,
#          '통신비': 1,
#          '멤버십': 1,
#          '혜택': 1,
#          '살펴보셨나요': 1,
#          '이프': 1,
#          '랜드': 1,
#          '컬러': 1,
#          '제페토': 1,
#          '메타': 1,
#          '하차': 1,
#          '사용자': 1,
#          '반토막': 1,
#          '테무': 1,
#          '악몽': 1,
#          '미니': 1,
#          '미스': 1,
#          '뭐기': 1,
#          '불륜': 1,
#          '폭로': 1,
#          '균형발전': 1,
#          '기조': 1,
#          '쏠린': 1,
#          '생태계': 1,
#          '재편': 1,
#          '신호탄': 1,
#          '국내': 1,
#          '질병': 1,
#          '코드': 1,
#          '등재': 1,
#          '막을까': 1,
#          '용량': 1,
#          '올라도': 1,
#          '점유': 1,
#          '하락': 1,
#          '스노우플레이크': 1,
#          '서밋': 1,
#          '샘': 1,
#          '올트먼': 1,
#          '쓰는': 1,
#          '조건': 1,
#          '신동아': 1,
#          '붕괴': 1,
#          '보강': 1,
#          '구조': 1,
#          '단기간': 1,
#          '다수': 1,
#          '중립': 1,
#          '위협': 1,
#          '이란': 1,
#          '개국': 1,
#          '고문': 1,
#          '시사': 1,
#          '서부': 1,
#          '지법': 1,
#          '폭도': 1,
#          '지치지': 1,
#          '마십시오': 1,
#          '잊혀가는': 1,
#          '참사': 1,
#          '착한': 1,
#          '유가족': 1,
#          '통계물리학': 1,
#          '자상': 1,
#          '수상자': 1,
#          '만난': 1,
#          '나오기까지': 1,
#          '취재': 1,
#          '뒷담화': 1,
#          '협회': 1,
#          '보': 1,
#          '정치인': 1,
#          '문답': 1,
#          '일반': 1,
#          '공인': 1,
#          '방위': 1,
#          '성폭력': 1,
#          '없음': 1,
#          '의결': 1,
#          '지사': 1,
#          '인천': 1,
#          '지역구': 1,
#          '유럽': 1,
#          '보인다': 1,
#          '철저': 1,
#          '조사': 1,
#          '세월호': 1,
#          '가시있는': 1,
#          '지하': 1,
#          '간': 1,
#          '잡음': 1,
#          '배워야': 1,
#          '지지자': 1,
#          '점집': 1,
#          '시신': 1,
#          '무속인': 1,
#          '생활고': 1,
#          '힘들어': 1,
#          '여': 1,
#          '경제성장률': 1,
#          '치': 1,
#          '민간': 1,
#          '소비': 1,
#          '직급': 1,
#          '무관': 1,
#          '하게': 1,
#          '서': 1,
#          '철봉': 1,
#          '의미': 1,
#          '건재': 1,
#          '보여주는': 1,
#          '비상계엄': 1,
#          '기록물': 1,
#          '홍': 1,
#          '총회': 1,
#          '같다': 1,
#          '인터넷': 1,
#          '망': 1,
#          '그대로': 1,
#          '황량': 1,
#          '경전': 1,
#          '새로운': 1,
#          '기회': 1,
#          '만든다': 1,
#          '신호': 1,
#          '흔한': 1,
#          '잘피': 1,
#          '멸종위기': 1,
#          '이중고': 1,
#          '겪는': 1,
#          '여성신문': 1,
#          '평등': 1,
#          '실현': 1,
#          '벌거': 1,
#          '벗은': 1,
#          '남자': 1,
#          '연애': 1,
#          '하고': 1,
#          '싶고': 1,
#          '도태': 1,
#          '되긴': 1,
#          '한강': 1,
#          '온다': 1,
#          '권하는': 1,
#          '책': 1,
#          '몰': 1,
#          '남성은': 1,
#          '추진': 1,
#          '외환위기': 1,
#          '맞는': 1,
#          '골라': 1,
#          '볼까': 1,
#          '기간': 1,
#          '끝나니': 1,
#          '덤핑': 1,
#          '공세': 1,
#          '회계감사': 1,
#          '부실': 1,
#          '질라': 1,
#          '예의': 1,
#          '주시': 1,
#          '은행': 1,
#          '보따리': 1,
#          '벗고': 1,
#          '돈줄': 1,
#          '부상': 1,
#          '치아': 1,
#          '장기': 1,
#          '보존': 1,
#          '열렸다': 1,
#          '세포': 1,
#          ...})

# %%
# most_common(숫자) : 가장 카운트가 많은 숫자 개수 만큼
stat = Counter(words).most_common(50)
stat
# Out:
# [('이재명', 91),
#  ('대통령', 90),
#  ('정부', 47),
#  ('속보', 42),
#  ('신문', 37),
#  ('코스피', 37),
#  ('법', 34),
#  ('돌파', 33),
#  ('보기', 30),
#  ('선', 30),
#  ('대법관', 29),
#  ('조희', 28),
#  ('증원', 28),
#  ('해보세요', 28),
#  ('국민', 27),
#  ('것', 27),
#  ('장', 25),
#  ('관심', 25),
#  ('대선', 24),
#  ('트럼프', 24),
#  ('김민석', 24),
#  ('개월', 23),
#  ('일보', 23),
#  ('공론장', 23),
#  ('마련', 23),
#  ('경제', 22),
#  ('희망', 22),
#  ('국회', 22),
#  ('경호', 22),
#  ('이', 21),
#  ('만', 20),
#  ('협의', 20),
#  ('의', 19),
#  ('대', 19),
#  ('민생', 17),
#  ('경찰', 17),
#  ('명', 17),
#  ('제', 16),
#  ('뉴스', 15),
#  ('새', 14),
#  ('모두', 14),
#  ('총리', 14),
#  ('기자', 13),
#  ('계속', 13),
#  ('통합', 13),
#  ('첫', 13),
#  ('원전', 13),
#  ('할', 13),
#  ('힘', 13),
#  ('상황', 12)]

# %%
# 폰트 불러오기: ../my_fonts/NanumGothic-ExtraBold.ttf
from wordcloud import WordCloud

# %%
wc = WordCloud(font_path='../my_fonts/NanumGothic-ExtraBold.ttf', 
                background_color='white', 
                max_font_size=200,
                width=700, height=450)
cloud = wc.generate_from_frequencies(dict(stat))

# %%
cloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=700x450>

# %%
# 워드 클라우드 이미지를 파일로 저장
from time import strftime
cloud.to_file(f"{strftime('%Y%m%d%H')}_news.jpg")
